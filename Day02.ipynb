# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarya-Musale/Python/blob/main/Day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python is dynamically types language
# Static typing- int a = 20 | string s = "python"
# Dynamic Typing- a = 20 | s = 'python'
a = 20
type(a)
# Out:
# int

# %%
s = 'python'
type(s)
# Out:
# str

# %%
x = 'python'
type(x)
# Out:
# str

# %%
x = 10
type(x)
# Out:
# int

# %%
y = 10
id(y)
# Out:
# 11645640

# %%
#List is mutable
e = [1,2,3,4]
id(e)
# Out:
# 133969069829120

# %%
t = [1,2,3,4]
id(t)
# Out:
# 133969070289344

# %%
# String in python
# Syntax: ""

type('c++')
type('.net')
# Out:
# str

# %%
# List
# Syntax:[]

q = [1,2,3,4] # homo
r = ['A','B','C'] # homo
p = ['X',10,22.22,'Y'] # hetro

type(p),type(q),type(r)
# Out:
# (list, list, list)

# %%
#Tuple
# Syntax: ()

t1 = (1,2,3)
t2 = ('A','B','C')
t3 = ('X',10,22.22,'Y')

type(t1),type(t2),type(t3)
# Out:
# (tuple, tuple, tuple)

# %%
#Diff  btw List and Tuple

p = ['X',10,22.22,'Y']

t1 = (1,2,3)


p.append(100)
p
# Out:
# ['X', 10, 22.22, 'Y', 100]

# %%
list = [20,30,40,50]
print("reverse the elements:",list[-1])
# Out:
# reverse the elements: 50

# %%
x = 10
id(x)
# Out:
# 11645640

# %%
y = 10
id(y)
# Out:
# 11645640

# %%
x = 10
id(x)
# Out:
# 11645640

# %%
y = 15
id(y)
# Out:
# 11645800

# %%
x = 10
y = 15
id(x),id(y)
# Out:
# (11645640, 11645800)

# %%
x = 20
x = 10
id(x),id(x)
# Out:
# (11645640, 11645640)

# %%
y = 15
y = 20
id(y),id(y)
# Out:
# (11645960, 11645960)
