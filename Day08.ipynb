# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarya-Musale/Python/blob/main/Day08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Duplicated are not allowed in set
#it doesn't preserves order

#this is bcz of background data structure- Hash Table

#indexing and slicing are not supported

# %%
#bucket number--> hash value
-11%2
# Out:
# 1

# %%
help(set.pop)
# Out:
# Help on method_descriptor:
#
# pop(...) unbound builtins.set method
#     Remove and return an arbitrary set element.
#     Raises KeyError if the set is empty.

# %%
s = {-11,4,10,230}
s
# Out:
# {-11, 4, 10, 230}

# %%
s.pop()
# Out:
# 10

# %%
# can we add index here
s.pop(-1) #set pop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1832/803334754.py in <cell line: 0>()
# ----> 1 s.pop(-1)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
#How to create an empty set
d = set()
type(d)
# Out:
# set

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
# ...

# %%
#Typecasting/Type conversion
#-We as a user wants to change a data type from one form to another
#-ex. list--> tuple | tuple--> set

# %%
a = [1,2,3,4,1,1,2,2,3,3]
a
# Out:
# [1, 2, 3, 4, 1, 1, 2, 2, 3, 3]

# %%
#write a program to remove the duplicates
set(a) #this is a temporary conversion
# Out:
# {1, 2, 3, 4}

# %%
tuple(a)
# Out:
# (1, 2, 3, 4, 1, 1, 2, 2, 3, 3)

# %%
#take an input from the user
per_day = float(input('Enter your per day income:Rs.'))
days = float(input('Working days:'))

print('Final Salary is',per_day*days)
# Out:
# Enter your per day income:Rs.1000
# Working days:5
# Final Salary is 5000.0

# %%
#Assignment: create a simple bill of Grocery.Take 3-4 inputs and print the final bill
fruits = eval(input('Enter amt of fruits:'))
milk = eval(input('Enter amt of milk:'))
bread = eval(input('Enter amt of bread:'))
biscuits = eval(input('Enter amt of biscuits:'))

print('Final Bill is:',fruits+milk+bread+biscuits)
# Out:
# Enter amt of fruits:150
# Enter amt of milk:70
# Enter amt of bread:50
# Enter amt of biscuits:40
# Final Bill is: 310

# %%
#Ps: Take an input list/set/tuple/dict from user
#eval() function will help you to take the data in its original format
data = eval(input('Enter your data:'))
print(data)
print(type(data))
# Out:
# Enter your data:'dhvjdfh'
# dhvjdfh
# <class 'str'>

# %%
'aarya','shivani'

#Rule: comma separated values in python are by default Tuple
# Out:
# ('aarya', 'shivani')

# %%
{1,2,3},(1,'python',20.6),[1,'java',5]
# Out:
# ({1, 2, 3}, (1, 'python', 20.6), [1, 'java', 5])

# %%
#Purpose of eval()
#To take input in original format
#To evaluate
