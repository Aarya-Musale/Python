# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarya-Musale/Python/blob/main/Day04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **List Methods**

# %%
#Syntax:[]

# %%
#Features of List:
#Background Data Structure is array
#It supports Indexing and Slicing
#We can create homo. and hetro. list
#It preserves sequence order
#It allows duplicate order
#List is mutable in nature

#Que: Expalin features of a list?

# %%
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
l = [1,2,3]
l.append(4)
l
# Out:
# [1, 2, 3, 4]

# %%
#Que: How to create an empty list?
#1st approach
a = []  #This is an empty list
a

#2nd approach
b = list()
b
# Out:
# []

# %%
#Assignment: How to create an empty string:

# %%
#To add elements in empty list/a normal then use append(object) method
a
a.append(100)
a

#Operations in list are inplace/permanant
# Out:
# [100]

# %%
#Assignment: Try to add str,list,tuple,set,dict

# %%
a.append('Python')
a
# Out:
# [100, 'Python']

# %%
a.append([20,30])
a
# Out:
# [100, 'Python', [20, 30]]

# %%
a.append((2,4))
a
# Out:
# [100, 'Python', [20, 30], (2, 4)]

# %%
a.append({5})
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}]

# %%
a.append({'a':12,'b':13})
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}]

# %%
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}]

# %%
data = (2,3,4)
data
# Out:
# (2, 3, 4)

# %%
#add above data in a
a.append(data) # this will add a complete tuple in a
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}, (2, 3, 4)]

# %%
#add c++
a.append('c++')
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}, (2, 3, 4), 'c++']

# %%
#append adds a complete object as it is

# %%
b
# Out:
# []

# %%
b.extend(data)
b
# Out:
# [2, 3, 4]

# %%
b.extend('C++')
b
# Out:
# [2, 3, 4, 'C', '+', '+']

# %%
#Que: append vs extend

# %%
#To remove elements from list we have 2 methods
#pop (default removes last element)

b.pop()
b
# Out:
# [2, 3, 4, 'C', '+']

# %%
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}, (2, 3, 4), 'c++']

# %%
a.pop()
# Out:
# 'c++'

# %%
a
# Out:
# [100, 'Python', [20, 30], (2, 4), {5}, {'a': 12, 'b': 13}, (2, 3, 4)]

# %%
#Pop default removes last element

# %%
k = [1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# pop(index)--->we can remove element with its index
k.pop(2)
# Out:
# 3

# %%
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
# remove(value)
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)
k
# Out:
# [1, 2, 4, 5, 7]

# %%
# What is diff btw pop and remove?

# %%
help(k.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
t = [1,2,3,1,1,4,5,1,1]
t.remove(1)
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
t.remove(1)
t
# Out:
# [2, 3, 1, 4, 5, 1, 1]

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
# remove all elements
k.clear()
k
# Out:
# []

# %%
t
# Out:
# [2, 3, 1, 4, 5, 1, 1]

# %%
# shallow copy: list is with same element but ids are diff

x = t.copy()
x
# Out:
# [2, 3, 1, 4, 5, 1, 1]

# %%
# add -1 in x

x.append(-1)
x
# Out:
# [2, 3, 1, 4, 5, 1, 1, -1]

# %%
t
# Out:
# [2, 3, 1, 4, 5, 1, 1]

# %%
id(t),id(x)
# Out:
# (136599015244288, 136599015267712)

# %%
y = x
y
# Out:
# [2, 3, 1, 4, 5, 1, 1, -1]

# %%
# in above case we have 1 obj with diff names x, y hence
# if we change in either x/y changes will get reflected in both the list

x.append('python')
x
# Out:
# [2, 3, 1, 4, 5, 1, 1, -1, 'python']

# %%
y
# Out:
# [2, 3, 1, 4, 5, 1, 1, -1, 'python']

# %%
id(x),id(y)
# Out:
# (136599015267712, 136599015267712)

# %%
r1 = []
r1
# Out:
# []

# %%
r2 = r1
r2
# Out:
# []

# %%
r1.append(500)
r1
# Out:
# [500]

# %%
r2
# Out:
# [500]

# %%
#Assignment: Can we add tuple to a list using extend?
#Ans: Yes, we can add tuple to a list using extend because tuple is iterable.

# %%
#To add element at specific index
#We use insert method
#We require to give specific index and the element you want to add

fruits = ['apple','mango','banana']
fruits.insert(2,'cherry')
fruits
# Out:
# ['apple', 'mango', 'cherry', 'banana']

# %%
vegies = ['tomato','potato']
vegies
# Out:
# ['tomato', 'potato']

# %%
vegies.extend(fruits)
vegies
# Out:
# ['tomato', 'potato', 'apple', 'mango', 'cherry', 'banana']

# %%
fruits
# Out:
# ['apple', 'mango', 'cherry', 'banana']

# %%
fruits[2] = 'guava'
fruits
# Out:
# ['apple', 'mango', 'guava', 'banana']

# %%
fruits.remove('guava')
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
fruits.append('cherry')
fruits
# Out:
# ['apple', 'mango', 'banana', 'cherry']

# %%
fruits.append(100)
fruits
# Out:
# ['apple', 'mango', 'banana', 'cherry', 100]

# %%
# To remove more than one elements

del fruits[0:2]
fruits
# Out:
# ['banana', 'cherry', 100]

# %%
#To add more than one element at specific index

fruits
# Out:
# ['banana', 'cherry', 100]

# %%
fruits.insert(1,'mango')
fruits
# Out:
# ['banana', 'mango', 'cherry', 100]

# %%
nums = [1,2,3,4,5]
nums.insert(2,10)
nums
# Out:
# [1, 2, 10, 3, 4, 5]

# %%
#Returns the index of the element you want
nums.index(10)
# Out:
# 2

# %%
#Returns the count of the specified item in the list

list = ['A','B',22,10,55,'A']
list.count('A')
# Out:
# 2

# %%
#Sort:sorts the list in ascending/descending order
nums.sort()
nums
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
num = [5,7,3,10,1,2,8,9]
num.sort()
num
# Out:
# [1, 2, 3, 5, 7, 8, 9, 10]

# %%
num.reverse()
num
# Out:
# [10, 9, 8, 7, 5, 3, 2, 1]

# %%
num.sort()
num
# Out:
# [1, 2, 3, 5, 7, 8, 9, 10]

# %%
# diff btw pop and remove
# Ans:pop()
#     pop uses index position to remove element
#     if index position is not given it by default removes the last element
#     even if there are duplicates it only removes element at index position


# Ans:remove()
#     remove uses value to remove element
#     Here giving value is compulsory,without giving value it will give you error
#     if any duplicates are there,then frist occured element is removed

# %%
num
# Out:
# [1, 2, 3, 5, 7, 8, 9, 10]

# %%
num.index(2)
# Out:
# 1
