# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarya-Musale/Python/blob/main/Day07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {} #Empty dict
type(a)
# Out:
# dict

# %%
#set vs dict

# %%
b = {1:100,2:200,3:300}
b
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
c = {'name':'aarya','age':23}
c
# Out:
# {'name': 'aarya', 'age': 23}

# %%
#Features of Dictionary
#Duplicates are not allowed
g = {1:100,1:1000,1:'JAVA'}
g
# Out:
# {1: 'JAVA'}

# %%
#Rule: If we have multiple values with same key present in the dict then it takes last recent pair
#In above case 1:'JAVA' is the last key-value pair

# %%
h = {1:100,2:200,3:'JAVA'}
h
# Out:
# {1: 100, 2: 200, 3: 'JAVA'}

# %%
h = {1:100,[2,4]:200,3:'JAVA'} #Here we are trying to set a list as a key which is not allowed- check below rule
h
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3614/295223641.py in <cell line: 0>()
# ----> 1 h = {1:100,[2,4]:200,3:'JAVA'}
#       2 h
#
# TypeError: unhashable type: 'list'

# %%
#In set we cannot give/add MUTABLE objects
#& in dict we cannot set key as a mutable object

# %%
#Duplicate keys are not allowed but duplicate values are allowed
t = {1:100,2:100,3:100}
t
# Out:
# {1: 100, 2: 100, 3: 100}

# %%
u = {1:'python',2:'python',3:'python'}
u
# Out:
# {1: 'python', 2: 'python', 3: 'python'}

# %%
x = {} #Empty dict
x
# Out:
# {}

# %%
#add pair/s
x.update({1:10,2:20})
x
# Out:
# {1: 10, 2: 20}

# %%
#we can also use update to update already exisiting value of concerned key
x.update({1:30})
x
# Out:
# {1: 30, 2: 20}

# %%
#add new pair
x.update({3:'python'})
x
# Out:
# {1: 30, 2: 20, 3: 'python'}

# %%
#We can also use set default method
help(x.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(key, default=None, /) method of builtins.dict instance
#     Insert key with a value of default if key is not in the dictionary.
#
#     Return the value for key if key is in the dictionary, else default.

# %%
x
# Out:
# {1: 30, 2: 20, 3: 'python'}

# %%
x.setdefault(4) #for key 4 it will add None as a value 4:None
x
# Out:
# {1: 30, 2: 20, 3: 'python', 4: None}

# %%
#Instead of None we want anothe value
x.setdefault(5,'ABC')
x
# Out:
# {1: 30, 2: 20, 3: 'python', 4: None, 5: 'ABC'}

# %%
#If key is already present and we try to give a new value or if we keep it empty
x.setdefault(5) #If key already exist in the dict,then setdefault returns its value,if won't update it to None
# Out:
# 'ABC'

# %%
x
# Out:
# {1: 30, 2: 20, 3: 'python', 4: None, 5: 'ABC'}

# %%
#To fetch only keys
x.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
#To fetch only values
x.values()
# Out:
# dict_values([30, 20, 'python', None, 'ABC'])

# %%
#To fetch keys and values
x.items()
# Out:
# dict_items([(1, 30), (2, 20), (3, 'python'), (4, None), (5, 'ABC')])

# %%
#Assignment: Check remaining methods of dictionary
#copy():
y = x.copy()
y
# Out:
# {1: 30, 2: 20, 3: 'python', 4: None, 5: 'ABC'}

# %%
#get():
x.get(2)
# Out:
# 20

# %%
#pop():
x.pop(1)
# Out:
# 30

# %%
x
# Out:
# {2: 20, 3: 'python', 4: None, 5: 'ABC'}

# %%
#popitem():
x.popitem()
# Out:
# (5, 'ABC')

# %%
x
# Out:
# {2: 20, 3: 'python', 4: None}

# %%
#clear():
x.clear()

# %%
x
# Out:
# {}
